# %% [markdown]
# <a href="https://colab.research.google.com/github/amaziarczyk/Data-Science/blob/main/Klasteryzacja/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DBSCAN
#
#  Oparte na kursie Machine Learning Bootcamp w języku Python cz.II - od A do Z
#
#  e-smartdata.org

# %% [markdown]
# ### <a name='0'></a> Import bibliotek

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### <a name='1'></a> Wygenerowanie danych i wizualizacja

# %%
from sklearn.datasets import make_blobs

data = make_blobs(n_samples=1200, centers=3, cluster_std=1.2, random_state=42)[0]
df = pd.DataFrame(data, columns=['x', 'y'])
px.scatter(df, 'x', 'y', width=750, height=500, title='Klasteryzacja')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4feab4e7-d01f-49bd-bf31-e40ace131afd" class="plotly-graph-div" style="height:500px; width:750px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4feab4e7-d01f-49bd-bf31-e40ace131afd")) {
#                     Plotly.newPlot(
#                         '4feab4e7-d01f-49bd-bf31-e40ace131afd',
# ...

# %% [markdown]
# ### <a name='2'></a> DBSCAN

# %%
from sklearn.cluster import DBSCAN

cluster = DBSCAN(eps=0.5, min_samples=5)
cluster.fit(data)
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
cluster.labels_[:10]
# Out:
# array([0, 1, 0, 2, 2, 2, 0, 2, 0, 0])

# %%
df['klaster']=cluster.labels_
df.head()
# Out:
#           x          y  cluster  klaster
# 0  4.174067   2.177669        0        0
# 1 -8.166919  -6.593013        1        1
# 2  6.535365   1.345738        0        0
# 3 -4.422511   8.295036        2        2
# 4 -2.075523  10.859930        2        2

# %% [markdown]
# ### <a name='3'></a> DBSCAN - wizualizacja

# %%
px.scatter(df, 'x', 'y', 'klaster', width=850, height=500, title='DBSCAN(eps=0.5, min_samples=5)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="94b8d4da-8164-4914-93ee-3987a3381213" class="plotly-graph-div" style="height:500px; width:850px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94b8d4da-8164-4914-93ee-3987a3381213")) {
#                     Plotly.newPlot(
#                         '94b8d4da-8164-4914-93ee-3987a3381213',
# ...

# %%
cluster = DBSCAN(eps=0.5, min_samples=7)
cluster.fit(data)

df['cluster'] = cluster.labels_
px.scatter(df, 'x', 'y', 'cluster', width=850, height=500, title='DBSCAN(eps=0.5, min_samples=7)',
           )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c86def9d-df33-40fd-af58-32acc0b5c424" class="plotly-graph-div" style="height:500px; width:850px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c86def9d-df33-40fd-af58-32acc0b5c424")) {
#                     Plotly.newPlot(
#                         'c86def9d-df33-40fd-af58-32acc0b5c424',
# ...

# %%
cluster = DBSCAN(eps=0.8, min_samples=5)
cluster.fit(data)

df['cluster'] = cluster.labels_
px.scatter(df, 'x', 'y', 'cluster', width=950, height=500, title='DBSCAN(eps=0.7, min_samples=5)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a4d9e3f-fdb1-4a10-81f6-8123283dddfa" class="plotly-graph-div" style="height:500px; width:950px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a4d9e3f-fdb1-4a10-81f6-8123283dddfa")) {
#                     Plotly.newPlot(
#                         '4a4d9e3f-fdb1-4a10-81f6-8123283dddfa',
# ...
